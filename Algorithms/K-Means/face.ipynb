# %%
import PIL
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

# %%
image = PIL.Image.open("img.jpg")

X = np.array(image)
row_X = X.shape[0]
col_X = X.shape[1]

# %%
X.shape

# [
#     [[rgb], [rgb], [rgb]],
#     [[rgb], [rgb], [rgb]],
#     [[rgb], [rgb], [rgb]],
#     [[rgb], [rgb], [rgb]],
# ]
# Out:
# (1289, 2048, 3)

# %%
X = X.reshape(X.shape[0] * X.shape[1], 3)

# %%
model = KMeans(n_clusters=3)
model.fit(X);

# %%
labels = model.predict(X)

# %%
# [
#     [0, 1, 2, 2, 1],
#     [0, 1, 2, 2, 1],
#     [0, 1, 2, 2, 1],
# ]

# %%
res = np.zeros((labels.shape[0], 3))

# %%
for k in range(3):
    res[labels == k] = model.cluster_centers_[k] / 255

# %%
res = res.reshape(row_X, col_X, 3)

# %%
plt.imshow(res);
